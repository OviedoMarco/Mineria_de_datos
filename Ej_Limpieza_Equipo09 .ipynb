# %% [markdown]
# # Practica 1 - Limpieza de datos
#
# *Equipo: 9*
#
# *Grupo 002: Clase Del Miercoles*
#
# *Marco Antonio Oviedo Acevedo    1851698*
#
# *Nayelli Alondra Gaona Allende   1860995*
#
# *Eliud Moreno Narvaez            1863955*
#
# *Luis Adrian Navarro Garcia    1866581*

# %% [markdown]
# ## 1) Titulo de la base de datos

# %% [markdown]
# ***a)
# Nombre con el que se encuentra en la pagina encontrada.***

# %% [markdown]
# *Netflix Movies and TV Shows*

# %% [markdown]
# ***b)
# Url de la pagina.***

# %% [markdown]
# https://www.kaggle.com/shivamb/netflix-shows

# %% [markdown]
# ## 2) Introducción General

# %% [markdown]
# ***a)
# Realizar una descripcion sobre el tema en donde se desarrolla la base de datos.***

# %% [markdown]
# Programas de televisión y películas que figuran en Netflix
# Este conjunto de datos consta de programas de televisión y películas disponibles en Netflix a partir de 2019. El conjunto de datos se recopila de Flixable, que es un motor de búsqueda de Netflix de terceros.
#
# En 2018, publicaron un informe interesante que muestra que la cantidad de programas de televisión en Netflix casi se ha triplicado desde 2010. La cantidad de películas del servicio de transmisión ha disminuido en más de 2.000 títulos desde 2010, mientras que la cantidad de programas de televisión casi se ha triplicado. Será interesante explorar qué otros conocimientos se pueden obtener del mismo conjunto de datos.
#
# Al integrar este conjunto de datos con otros conjuntos de datos externos, como las calificaciones de IMDB, los tomates podridos también pueden proporcionar muchos hallazgos interesantes.

# %% [markdown]
# ## 3) Tecnicas De Limpieza De Datos

# %% [markdown]
# ***a) Importar librerias y bases de datos.***

# %% [markdown]
# En esta seccion se importaran las librerias que se podrian utilizar para la lectura de nuestros datos

# %%
#import "Libreria" as "Abreviacion"
import pandas as pd #pd es la abreviacion que usaremos para pandas
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
mainpath = "/Python-ML/datasets/"
filename = "/netflix_titles.csv"
fullpath = os.path.join(mainpath, filename)

# %%
data = pd.read_csv("DataSets/netflix_titles.csv") 
# Agregamos .. para subir un nivel

# %% [markdown]
# ***Visualizacion de datos.***

# %% [markdown]
# obtenemos una vista previa de nuestros datos para saber como a que nos enfrentamos

# %%
data.head() #esta funcion nos enseña una visualizacion de las primeras filas de nuestra data
# El rize csv tiene 31 columnas
# Out:
#   show_id     type  title           director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie   7:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 cast        country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#           date_added  release_year rating   duration  \
# 0    August 14, 2020          2020  TV-MA  4 Seasons
# 1  December 23, 2016          2016  TV-MA     93 min
# 2  December 20, 2018          2011      R     78 min
# 3  November 16, 2017          2009  PG-13     80 min
# ...

# %% [markdown]
# ***Descripción basica de columnas***

# %% [markdown]
# Observamos los encabezados de mi dataset

# %%
data.columns.values #Esta funcion nos mostrara los titulos de nuestras columnas
# Out:
# array(['show_id', 'type', 'title', 'director', 'cast', 'country',
#        'date_added', 'release_year', 'rating', 'duration', 'listed_in',
#        'description'], dtype=object)

# %% [markdown]
# Analizamos las ultimas 8 filas de mi dataset para ver como se comporta

# %%
data.tail(8) #observamos las ultimas 8 filas
# Out:
#      show_id     type                                    title      director  \
# 7779   s7780  TV Show                                Zona Rosa           NaN
# 7780   s7781    Movie                                      Zoo  Shlok Sharma
# 7781   s7782    Movie                                     Zoom  Peter Hewitt
# 7782   s7783    Movie                                     Zozo   Josef Fares
# 7783   s7784    Movie                                   Zubaan   Mozez Singh
# 7784   s7785    Movie                        Zulu Man in Japan           NaN
# 7785   s7786  TV Show                    Zumbo's Just Desserts           NaN
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS      Sam Dunn
#
#                                                    cast  \
# 7779  Manu NNa, Ana Julia Yeyé, Ray Contreras, Pablo...
# 7780  Shashank Arora, Shweta Tripathi, Rahul Kumar, ...
# 7781  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# ...

# %% [markdown]
# calculamos el numero de filas y columnas de nuestros datos

# %%
data.shape # (numero de filas,numero de columnas)
# Out:
# (7787, 12)

# %% [markdown]
# obtenemos un resumen de nuestras variables numericas

# %%
data.describe() #resumen de los estadísticos básicos de las variables numéricas.
# Out:
#        release_year
# count   7787.000000
# mean    2013.932580
# std        8.757395
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2018.000000
# max     2021.000000

# %% [markdown]
# en este paso ya nos damos cuenta que trabajaremos con variables categoricas pues solo contamos con una varible numerica

# %%
data.dtypes #mostraremos en pantalla el tipo de datos de mis variables
# Out:
# show_id         object
# type            object
# title           object
# director        object
# cast            object
# country         object
# date_added      object
# release_year     int64
# rating          object
# duration        object
# listed_in       object
# description     object
# dtype: object

# %% [markdown]
# Manejamos nuestros datos nulos donde vemos que en algunas columnas tenemos datos incompletos pero la variable que más utlizaremos no contiene variables nulos

# %%
#veamos si tenemos algun dato null en nuestra variable que más utilizaremos
pd.isnull(data["show_id"]).values.ravel().sum()
# Out:
# 0

# %%
#veamos si tenemos algun dato null en nuestro dataset
pd.isnull(data).values.ravel().sum()
# Out:
# 3631

# %%
#Aunque no se haya encontrado aplicaremos la funcion para remover todos los nulls
data_sin_nulos = data
data_sin_nulos = data.dropna(axis=0, how="all")
#Lo guardamos en otra variable para no perder informacion

# %%
data_sin_nulos.dropna(axis=0, how="any")
# Out:
#      show_id     type       title           director  \
# 1         s2    Movie        7:19  Jorge Michel Grau
# 2         s3    Movie       23:59       Gilbert Chan
# 3         s4    Movie           9        Shane Acker
# 4         s5    Movie          21     Robert Luketic
# 5         s6  TV Show          46        Serdar Akar
# ...      ...      ...         ...                ...
# 7778   s7779    Movie  Zombieland    Ruben Fleischer
# 7780   s7781    Movie         Zoo       Shlok Sharma
# 7781   s7782    Movie        Zoom       Peter Hewitt
# 7782   s7783    Movie        Zozo        Josef Fares
# 7783   s7784    Movie      Zubaan        Mozez Singh
#
#                                                    cast  \
# 1     Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2     Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3     Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4     Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...

# %%
data_sin_nulos.fillna(0)
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                     0  João Miguel, Bianca Comparato, Michel Gomes, R...
# ...

# %% [markdown]
# Como no tenemos variables categoricas no aplicaremos ningun analisis de variables Dummy

# %% [markdown]
# ***Clasificacion de datos***

# %% [markdown]
# utilizamos como practica la variable type para crear un categorizacion de varibles dummyn para poder manejarlas en un futuro

# %%
data["type"].head(10)
# Out:
# 0    TV Show
# 1      Movie
# 2      Movie
# 3      Movie
# 4      Movie
# 5    TV Show
# 6      Movie
# 7      Movie
# 8      Movie
# 9      Movie
# Name: type, dtype: object

# %% [markdown]
# En este paso creamos nuestras variables dummmy donde daremos valores de 1 si se cumple y 0 si no se cumple

# %%
dummy_type = pd.get_dummies(data["type"], prefix="type")

# %% [markdown]
# mostramos una previsualizacion del paso anterior

# %%
dummy_type.head(10)
# Out:
#    type_Movie  type_TV Show
# 0           0             1
# 1           1             0
# 2           1             0
# 3           1             0
# 4           1             0
# 5           0             1
# 6           1             0
# 7           1             0
# 8           1             0
# 9           1             0

# %%
column_name=data.columns.values.tolist()
column_name
# Out:
# ['show_id',
#  'type',
#  'title',
#  'director',
#  'cast',
#  'country',
#  'date_added',
#  'release_year',
#  'rating',
#  'duration',
#  'listed_in',
#  'description']

# %% [markdown]
# Este paso es muy importante pues aqui crearemos un dataframe agregando las nuevas variables que creamos llamadas type_"variable"

# %%
data = data.drop(["type"], axis = 1)

# %%
data = pd.concat([data, dummy_type], axis = 1)

# %%
def createDummies(df, var_name):
    dummy = pd.get_dummies(df[var_name], prefix=var_name)
    df = df.drop(var_name, axis = 1)
    df = pd.concat([df, dummy ], axis = 1)
    return df

# %% [markdown]
# las nuevas variables se colocaron al final de las columnas

# %%
createDummies(data_sin_nulos, "type")
# Out:
#      show_id                                    title           director  \
# 0         s1                                       3%                NaN
# 1         s2                                     7:19  Jorge Michel Grau
# 2         s3                                    23:59       Gilbert Chan
# 3         s4                                        9        Shane Acker
# 4         s5                                       21     Robert Luketic
# ...      ...                                      ...                ...
# 7782   s7783                                     Zozo        Josef Fares
# 7783   s7784                                   Zubaan        Mozez Singh
# 7784   s7785                        Zulu Man in Japan                NaN
# 7785   s7786                    Zumbo's Just Desserts                NaN
# 7786   s7787  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS           Sam Dunn
#
#                                                    cast  \
# ...

# %% [markdown]
# ***Cambiar nombres de columnas***

# %%
data.columns = ['show_id', 'titulo', 'director', 'cast', 'pais', 'fecha_agregada',
       'release_year', 'rating', 'duracion', 'listed_in', 'descripcion',
       'type_Movie', 'type_TV Show'] #Cambiamos los nombres de las variables que estan en ingles

# %%
data.columns #Esto nos ayudara en analisis posteriores
# Out:
# Index(['show_id', 'titulo', 'director', 'cast', 'pais', 'fecha_agregada',
#        'release_year', 'rating', 'duracion', 'listed_in', 'descripcion',
#        'type_Movie', 'type_TV Show'],
#       dtype='object')
